# %%
pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.6 MB 3.8 MB/s eta 0:00:01
# ...
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx
import pandas as pd
pd.set_option('max_rows', 400)
import matplotlib.pyplot as plt


texas_df = pd.read_csv('http://workbook.craftingdigitalhistory.ca/supporting%20materials/texaslinks.csv')

# take a look
texas_df


G = networkx.from_pandas_edgelist(texas_df, 'source', 'target', 'weight')

# and then we'll draw it!

networkx.draw(G)

# %%
plt.figure(figsize=(8,8))
networkx.draw(G, with_labels=True, node_color='skyblue', width=.3, font_size=6)

# %%
networkx.degree(G)
# Out:
# DegreeView({'Daniel Webster': 1, 'Isaac Van Zandt': 7, 'A Friend of Treat in Mexico': 1, 'a Friend of Treat in New Orleans Vitalba': 1, 'A. de Saligny': 8, 'Abner S. Lipscomb': 12, 'Anson Jones': 33, 'Ashbel Smith': 36, 'Ebenezer Allen': 10, 'James S. Mayfield': 14, 'Sam Houston': 13, 'Secretary of State Mayfield': 1, 'A. Gloux': 1, 'Alleye de Cyprey': 2, 'A. Hutchinson': 2, 'A. J. Donelson': 5, 'Secretary of State Allen': 2, 'A. J. Yates': 1, 'Stephen F. Austin': 2, 'A. M. Green': 3, 'Joseph Eve': 7, 'A. P. Upshur': 1, 'A. S. Wright': 6, 'Barnard E. Bee': 12, 'John Merle': 1, 'Mirabeau B. Lamar': 19, 'Nathaniel Amory': 8, 'William Bryan': 1, 'Wm. Bryan': 3, 'A. Somervell': 1, 'M. C. Hamilton': 2, 'A. T. Biimley': 1, 'David G. Burnet': 12, 'A. T. Burnley': 1, 'Abel Smith': 1, 'Lord Aberdeen': 5, 'Abb6 Anduz6': 2, 'Alc6e La Branche': 4, 'Geo. H. Flood': 3, 'Hamilton and Burnley': 3, 'James Hamilton': 21, 'James Hamilton and A. T. Bumley': 1, 'James Treat': 15, 'R. Pakenham': 10, 'Addr
# ...

# %%
degrees = dict(networkx.degree(G))
networkx.set_node_attributes(G, name='degree', values=degrees)
print(degrees)
# Out:
# {'Daniel Webster': 1, 'Isaac Van Zandt': 7, 'A Friend of Treat in Mexico': 1, 'a Friend of Treat in New Orleans Vitalba': 1, 'A. de Saligny': 8, 'Abner S. Lipscomb': 12, 'Anson Jones': 33, 'Ashbel Smith': 36, 'Ebenezer Allen': 10, 'James S. Mayfield': 14, 'Sam Houston': 13, 'Secretary of State Mayfield': 1, 'A. Gloux': 1, 'Alleye de Cyprey': 2, 'A. Hutchinson': 2, 'A. J. Donelson': 5, 'Secretary of State Allen': 2, 'A. J. Yates': 1, 'Stephen F. Austin': 2, 'A. M. Green': 3, 'Joseph Eve': 7, 'A. P. Upshur': 1, 'A. S. Wright': 6, 'Barnard E. Bee': 12, 'John Merle': 1, 'Mirabeau B. Lamar': 19, 'Nathaniel Amory': 8, 'William Bryan': 1, 'Wm. Bryan': 3, 'A. Somervell': 1, 'M. C. Hamilton': 2, 'A. T. Biimley': 1, 'David G. Burnet': 12, 'A. T. Burnley': 1, 'Abel Smith': 1, 'Lord Aberdeen': 5, 'Abb6 Anduz6': 2, 'Alc6e La Branche': 4, 'Geo. H. Flood': 3, 'Hamilton and Burnley': 3, 'James Hamilton': 21, 'James Hamilton and A. T. Bumley': 1, 'James Treat': 15, 'R. Pakenham': 10, 'Address of Tilg
# ...

# %%
degree_df = pd.DataFrame(G.nodes(data='degree'), columns=['node', 'degree'])
degree_df = degree_df.sort_values(by='degree', ascending=False)
degree_df
# Out:
#                                                   node  degree
# 7                                         Ashbel Smith      36
# 6                                          Anson Jones      33
# 40                                      James Hamilton      21
# 25                                   Mirabeau B. Lamar      19
# 52                               J. Pinckney Henderson      16
# 42                                         James Treat      15
# 9                                    James S. Mayfield      14
# 10                                         Sam Houston      13
# 32                                     David G. Burnet      12
# 23                                      Barnard E. Bee      12
# 87                                          James Webb      12
# 60                              Wm. Henry Daingerfield      12
# 5                                    Abner S. Lipscomb      12
# 164                                  Samuel A. Roberts      11
# ...

# %%
num_nodes_to_inspect = 10
degree_df[:num_nodes_to_inspect].plot(x='node', y='degree', kind='barh').invert_yaxis()

# %%
centrality = networkx.betweenness_centrality(G)

 print(sorted(centrality.items(), key = 
             lambda kv:(kv[1], kv[0])))
# Out:
# 0.14606028954381284
